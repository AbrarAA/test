# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/user/data/boston_housing.csv')

# %%
# aggregate or compare values , matp

# %%
df.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad    tax  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
'''
   1. Manipulate the dataframes using logical expressions and indexing
   2. Summarize you data
   3. Formulate testable questions about a dataset that is new to you
   4. Answer your using aggregrate tables and simple visualizations
   5. Communicate you findings
'''
# Out:
# ' 1. Manipulate the dataframes using logical expressions and indexing\n   2. Summarize you data\n   3. Formulate testable questions about a dataset that is new to you\n   4. Answer your using aggregrate tables and simple visualizations\n   5. Communicate you findings'

# %%
#1
#Manipulate the dataframes using logical expressions and indexing
df_sort=df.sort_values(by='medv',ascending=False)
df_sort.head()
# Out:
#         crim    zn  indus  chas    nox     rm    age     dis  rad    tax  \
# 283  0.01501  90.0   1.21     1  0.401  7.923   24.8  5.8850    1  198.0
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307.0
# 369  5.66998   0.0  18.10     1  0.631  6.683   96.8  1.3567   24  666.0
# 370  6.53876   0.0  18.10     1  0.631  7.016   97.5  1.2024   24  666.0
# 371  9.23230   0.0  18.10     0  0.631  6.216  100.0  1.1691   24  666.0
#
#      ptratio   black  lstat  medv
# 283     13.6  395.52   3.16  50.0
# 225     17.4  382.00   4.63  50.0
# 369     20.2  375.33   3.73  50.0
# 370     20.2  392.05   2.96  50.0
# 371     20.2  366.15   9.53  50.0

# %%
#2
#Summarize you data
print(df.describe())
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# 3
# Formulate testable questions about a dataset that is new to you


# Q: Does Distance to five Boston employment centres effect prices? 

# Q: is Crime effecting the price of the house? 

# Q: number of rooms vs ZN( roportion of residential land zoned for lots over 25,000 sq.ft.)

# Q: Does crime effect the prices of the houses on the harles River

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
# Q: Does Distance to employment centres effects prices? 

import matplotlib.pyplot as plt
plt.scatter(df.dis, df.medv)
plt.xlabel("Distance")
plt.ylabel("house Value")
plt.show()

# %%
# calculate covariance matrix
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Q: is Crime effecting the price of the house? 


plt.scatter(df.crim, df.medv)
plt.xlabel("Crime rate")
plt.ylabel("House Va")
plt.show()

# %%
# Q: number of rooms vs ZN( roportion of residential land zoned for lots over 25,000 sq.ft.)

#plt.scatter(df.rm, df.zn)
#plt.xlabel("Crime rate")
#plt.ylabel("House Value")
#plt.show()

# %%
df['chas'].unique()
# Out:
# array([0, 1])

# %%
# Q: Does crime effect the prices of the houses on the harles River

RV=df.groupby(['chas','crim'], as_index=False).agg({'medv':'mean'})

# %%
df['crim'].describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677083
# max       88.976200
# Name: crim, dtype: float64

# %%
#df['crim'].plot()
df['crim'].plot.hist(grid=True, bins=20, rwidth=1.9,
                   color='#607c8e')
plt.xlabel('crim')
plt.ylabel('count')
plt.grid(axis='y', alpha=0.75)

# %%
df['crim'].count()
# Out:
# 506

# %%
def is_crim_hi(df):
      return df.assign(crim_segment=np.where(df['crim'] >= 1, 'Hi', 'Low'))

# %%
df2=is_crim_hi(df)

# %%
df2.groupby(['crim_segment']).count()
# Out:
#               crim   zn  indus  chas  nox   rm  age  dis  rad  tax  ptratio  \
# crim_segment
# Hi             174  174    174   174  174  174  174  174  174  174      174
# Low            332  332    332   332  332  332  332  332  332  332      332
#
#               black  lstat  medv
# crim_segment
# Hi              174    174   174
# Low             332    332   332

# %%
df_Rev = df2[df2['chas']==1]
df_Rev['chas'].unique()
# Out:
# array([1])

# %%
df_Rev.groupby(['crim_segment'], as_index=False).agg({'medv':'mean'})
# Out:
#   crim_segment   medv
# 0           Hi  29.28
# 1          Low  27.81
